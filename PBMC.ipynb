# %%
import pandas as pd
from PixelGen.pxl_utils import compute_hotspot_pol_and_coloc_single_component
import anndata

# %%
DATASET_DIR = 'PixelGen/datasets/pbmc-pha-v2.0'

# %%
adata = anndata.read_h5ad(DA)
# Out:
#    Unnamed: 0                       upia                       upib  \
# 0           0  CGGGTTAGTTCATAATTAGCCCATT  ATTGCAGGTCGTTAGACAGATAGTG
# 1           1  CGTGATCAGACAACACGATGTGAGG  GCAGGGAACGACGGGTTTGCGTGGC
# 2           2  CTTTTAGTGTTTTCTATATTTCTTA  CGTTTGTTTTCTGCGAAATTACTGC
# 3           3  ACCCAGTTCTGCTCTGTCACGCAGT  GATGTGGAAATCTAATATGTATACC
# 4           4  TTGGTGTACTTCATTCTGTCGGGTC  AGCGGGGAGCTTGCGGTTTGTACAT
#
#           umi marker  sequence  count  unique_molecules_count  \
# 0  CGTCAGTGGG   CD19  ACCAACTT     15                       1
# 1  GAAGCGTCCT   CD19  ACCAACTT     15                       1
# 2  TGCGAGGGGG   CD19  ACCAACTT     15                       1
# 3  GAGTTTGGGA   CD19  ACCAACTT     14                       1
# 4  TAGTGGACCA   CD19  ACCAACTT     14                       1
#
#                   component      sample
# 0  RCVCMP0000000_resting_r1  resting_r1
# 1  RCVCMP0000001_resting_r1  resting_r1
# 2  RCVCMP0000002_resting_r1  resting_r1
# 3  RCVCMP0000004_resting_r1  resting_r1
# 4  RCVCMP0000005_resting_r1  resting_r1
