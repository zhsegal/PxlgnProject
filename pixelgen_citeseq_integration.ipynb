# %%
import anndata as ad
import scanpy as sc
import pandas as pd
# import cytovi
import matplotlib.pyplot as plt
import pixelator

# %%
# Two resting PBMC samples from Pixelgen V2 kit. Preprocessing includes:
#  1. Filtering based on minimum abundance
#  2. Tau marker specificty (see pixelgen docs)
#  3. DSB, CLR normalization in separate layers (main layer is CLR but counts are saved in separate layer)

pg_data = pixelator.read('datasets/combined_resting_data_FILTERED_NORMALIZED.pxl')
pxl_adata = pg_data.adata
print(pxl_adata)
print(pxl_adata.X[:5, :5])
pxl_adata.obs.head(5)
# Out:
# AnnData object with n_obs × n_vars = 2010 × 84
#     obs: 'pixels', 'a_pixels', 'b_pixels', 'antibodies', 'molecules', 'reads', 'mean_reads_per_molecule', 'median_reads_per_molecule', 'mean_b_pixels_per_a_pixel', 'median_b_pixels_per_a_pixel', 'mean_a_pixels_per_b_pixel', 'median_a_pixels_per_b_pixel', 'a_pixel_b_pixel_ratio', 'mean_molecules_per_a_pixel', 'median_molecules_per_a_pixel', 'leiden', 'tau_type', 'tau', 'sample', 'n_antibodies_by_counts', 'log1p_n_antibodies_by_counts', 'total_counts', 'log1p_total_counts'
#     var: 'nuclear', 'control', 'antibody_count-resting_r1', 'components-resting_r1', 'antibody_pct-resting_r1', 'antibody_count-resting_r2', 'components-resting_r2', 'antibody_pct-resting_r2', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'dendrogram_leiden', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_colors', 'umap'
# ...
